# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
df = pd.read_csv('cleaned_anime.csv')

# %% [markdown]
# EDA

# %% [markdown]
# Descriptive statistics of our dataset

# %%
df.describe()
# Out:
#               score  people_scored    popularity       members   recommended  \
# count  10142.000000   1.014200e+04  10142.000000  1.014200e+04  10142.000000
# mean       7.034946   5.558440e+04   6610.948629  1.085225e+05     17.823802
# std        0.594183   1.665118e+05   4709.591383  2.764894e+05     54.679235
# min        6.130000   1.040000e+02      1.000000  2.690000e+02      0.000000
# 25%        6.550000   1.405000e+03   2640.250000  4.284250e+03      0.000000
# 50%        6.960000   6.950500e+03   5676.500000  1.842050e+04      3.000000
# 75%        7.420000   3.648425e+04  10039.750000  8.541550e+04     12.000000
# max        9.270000   3.055585e+06  21945.000000  4.341420e+06   1209.000000
#
#        mixed_feelings  not_recommended  duration_min      episodes  \
# count    10142.000000     10142.000000  10098.000000  10073.000000
# mean         4.856734         3.703412     31.675183     15.824382
# std         12.030984        11.227326     27.509042     42.137903
# min          0.000000         0.000000      1.000000      1.000000
# 25%          0.000000         0.000000     22.000000      1.000000
# 50%          1.000000         0.000000     24.000000     11.000000
# 75%          4.000000         2.000000     27.000000     13.000000
# max        358.000000       418.000000    168.000000   1787.000000
#
#            favorites
# count   10142.000000
# mean     1245.011339
# std      7752.652418
# min         0.000000
# 25%         6.000000
# 50%        33.000000
# 75%       264.000000
# max    250681.000000

# %% [markdown]
# Distribution of scores. more anime fall in the score range of 6.0 to 7.5

# %%
df['score'].hist(bins=30)
plt.title('Distribution of Scores')
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Distribution of duration. Most of the dataset has

# %%
df['duration_min'].hist(bins=30)
plt.title('Distribution of Duration (minutes)')
plt.xlabel('Minutes')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Comparision of the Top ten genres in our dataset

# %%
df['genres'].value_counts().head(10).plot(kind='bar')
plt.title('Top Genres')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.xticks(rotation=45, ha="right")  
plt.show()

# %% [markdown]
# Correlation Matrix of our numeric columns

# %%
corr = df.select_dtypes(include=['number']).corr()

plt.figure(figsize=(10,8))

sns.heatmap(corr,
            annot=True,                
            fmt=".2f",                 
            cmap="coolwarm",           
            center=0,                  
            linewidths=0.5,            
            cbar_kws={"shrink": 0.8})  

plt.title("Correlation Matrix", fontsize=16, pad=20)
plt.xticks(rotation=45, ha="right")   
plt.yticks(rotation=0)                
plt.tight_layout()
plt.show()
